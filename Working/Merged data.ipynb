# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from IPython.display import Image

# %%
#import csvs of data to merge
AMS=pd.read_csv("../Resources/Amsterdam/amsterdam_clean.csv")
#AMS.head()
Boston=pd.read_csv("../Resources/boston/boston_clean.csv")
#Boston.head()
Nairobi=pd.read_csv("../Resources/Nairobi/nairobi_clean.csv")
#Nairobi.head()
SF=pd.read_csv("../Resources/San Francisco/sanfrancisco_clean.csv")
#SF.head()

# %%
#merging the four data frames
combined_city_data = pd.concat([AMS, SF,Boston,Nairobi], axis=1)
combined_city_data.head()
# Out:
#    Unnamed: 0    room_type       city             neighborhood  reviews  \
# 0           0  Shared room  Amsterdam  De Pijp / Rivierenbuurt        7
# 1           1  Shared room  Amsterdam             Centrum West       45
# 2           2  Shared room  Amsterdam          Watergraafsmeer        1
# 3           3  Shared room  Amsterdam             Centrum West        7
# 4           4  Shared room  Amsterdam   De Baarsjes / Oud West        1
#
#   overall_satisfaction accommodates bedrooms  price   latitude  \
# 0                  4.5            2      1.0  156.0  52.356209
# 1                  4.5            4      1.0  126.0  52.378518
# 2                  0.0            3      1.0  132.0  52.338811
# 3                  5.0            4      1.0  121.0  52.376319
# 4                  0.0            2      1.0   93.0  52.370384
#
#                          ...                             city neighborhood  \
# ...

# %%
# Set the 'city' to be our index for easy referencing of rows
Cty=combined_city_data.dropna(axis="columns", how="any")
Cty=Cty.dropna(axis="rows", how="any")
Cty=Cty.drop(columns=["latitude","longitude","bedrooms"])
Cty
# Out:
#        Unnamed: 0     room_type       city  \
# 0               0   Shared room  Amsterdam
# 1               1   Shared room  Amsterdam
# 2               2   Shared room  Amsterdam
# 3               3   Shared room  Amsterdam
# 4               4   Shared room  Amsterdam
# 5               5   Shared room  Amsterdam
# 6               6   Shared room  Amsterdam
# 7               7   Shared room  Amsterdam
# 8               8   Shared room  Amsterdam
# 9               9   Shared room  Amsterdam
# 10             10   Shared room  Amsterdam
# 11             11   Shared room  Amsterdam
# 12             12   Shared room  Amsterdam
# 13             13   Shared room  Amsterdam
# 14             14   Shared room  Amsterdam
# 15             15   Shared room  Amsterdam
# 16             16   Shared room  Amsterdam
# 17             17   Shared room  Amsterdam
# 18             18   Shared room  Amsterdam
# 19             19   Shared room  Amsterdam
# 20             20   Shared room  Amsterdam
# ...

# %%
h=Cty['room_type'].unique()
h
# Out:
# array(['Shared room', 'Entire home/apt', 'Private room'], dtype=object)

# %%
Cty.to_csv("airbnb_cleandata.csv")
