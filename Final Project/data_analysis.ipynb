# %%
# Dependencies
# %matplotlib inline
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
# San Fran Data
sanfran_clean = pd.read_csv("../Resources/San Francisco/sanfrancisco_clean.csv")
sanfran_clean.head()
# Out:
#    Unnamed: 0    room_type           city           neighborhood  reviews  \
# 0           0  Shared room  San Francisco            North Beach       93
# 1           1  Shared room  San Francisco            North Beach      115
# 2           2  Shared room  San Francisco  Downtown/Civic Center        4
# 3           3  Shared room  San Francisco  Downtown/Civic Center        8
# 4           4  Shared room  San Francisco     Financial District      125
#
#    overall_satisfaction  accommodates  bedrooms  price   latitude   longitude  \
# 0                   4.5             4       1.0  147.0  37.799263 -122.404322
# 1                   4.5             4       1.0  137.0  37.798920 -122.404085
# 2                   5.0             2       1.0  145.0  37.785847 -122.416518
# 3                   4.0            14       1.0  138.0  37.782079 -122.421775
# 4                   4.5             4       1.0   90.0  37.794410 -122.404725
#
# ...

# %%
# Nairobi Data
nairobi_clean = pd.read_csv("../Resources/Nairobi/nairobi_clean.csv")
nairobi_clean.head()
# Out:
#    Unnamed: 0    room_type     city neighborhood  reviews  \
# 0           0  Shared room  Nairobi      Nairobi        0
# 1           1  Shared room  Nairobi      Nairobi        0
# 2           2  Shared room  Nairobi      Nairobi        0
# 3           3  Shared room  Nairobi      Nairobi        1
# 4           4  Shared room  Nairobi      Nairobi        0
#
#    overall_satisfaction  accommodates  bedrooms  price  latitude  longitude  \
# 0                   0.0             3       1.0   45.0 -1.267705  36.765277
# 1                   0.0             3       1.0   45.0 -1.267733  36.766698
# 2                   0.0             3       1.0   60.0 -1.263079  36.795796
# 3                   0.0             3       1.0   60.0 -1.296785  36.778004
# 4                   0.0             2       1.0   60.0 -1.255794  36.752600
#
#                                             location
# 0  0101000020E6100000C4B0C398F4614240639CBF098548...
# ...

# %%
# Boston Data
boston_clean=pd.read_csv("../Resources/Boston/boston_clean.csv")
boston_clean.head()
# Out:
#    Unnamed: 0    room_type    city neighborhood  reviews  \
# 0           0  Shared room  Boston    South End        0
# 1           1  Shared room  Boston     Brighton        0
# 2           2  Shared room  Boston      Roxbury        0
# 3           3  Shared room  Boston    South End      106
# 4           4  Shared room  Boston     Back Bay        2
#
#    overall_satisfaction  accommodates  bedrooms  price   latitude  longitude  \
# 0                   0.0             1       1.0  500.0  42.341763 -71.075397
# 1                   0.0             1       1.0  225.0  42.360686 -71.141508
# 2                   0.0             2       1.0  150.0  42.337483 -71.079116
# 3                   5.0             3       1.0  125.0  42.344125 -71.070483
# 4                   0.0             1       1.0  105.0  42.351066 -71.080316
#
#                                             location
# 0  0101000020E6100000DB4DF04DD3C451C0CEFDD5E3BE2B...
# ...

# %%
# San Francisco Data
sf_clean = pd.read_csv("../Resources/San Francisco/sanfrancisco_clean.csv")
sf_clean.head()
# Out:
#    Unnamed: 0    room_type           city           neighborhood  reviews  \
# 0           0  Shared room  San Francisco            North Beach       93
# 1           1  Shared room  San Francisco            North Beach      115
# 2           2  Shared room  San Francisco  Downtown/Civic Center        4
# 3           3  Shared room  San Francisco  Downtown/Civic Center        8
# 4           4  Shared room  San Francisco     Financial District      125
#
#    overall_satisfaction  accommodates  bedrooms  price   latitude   longitude  \
# 0                   4.5             4       1.0  147.0  37.799263 -122.404322
# 1                   4.5             4       1.0  137.0  37.798920 -122.404085
# 2                   5.0             2       1.0  145.0  37.785847 -122.416518
# 3                   4.0            14       1.0  138.0  37.782079 -122.421775
# 4                   4.5             4       1.0   90.0  37.794410 -122.404725
#
# ...
